# %% [markdown]
# # Plotting resonances for reflection 50 ohm configuration 215mK

# %%
import pandas as pd
import numpy as np  
# from scipy import find_peaks
import matplotlib.pyplot as plt
import cmath
import math as m
from scipy.signal import find_peaks, peak_widths, savgol_filter
from scipy.optimize import curve_fit, leastsq
from pylab import *
import glob
from datetime import *

# %%
df=pd.read_csv(r"C:\Users\Anushka.PANDEY\Nextcloud\EPFL collab\sample1\reflection 50 ohms\VNA\Rawdata_4.7117_GHz_probe_0dB_215mK.txt", sep='\t', header=0)  
Frequency = df.iloc[:,0]          # 1st column
Simag = df.iloc[:, 1]       # 2nd column
Sreal = df.iloc[:, 2]       # 3rd column

# Combine into complex S21
S21_complex = np.array([complex(r, i) for r, i in zip(Sreal, Simag)])

# Compute magnitude in dB
S21_mag = np.abs(S21_complex)
S21_dB = 20 * np.log10(S21_mag)
S21_dB = S21_dB[1:]
f = Frequency[1:]
S21_complex = S21_complex[1:]
# Plot magnitude fit
plt.figure(figsize=(10, 6))
plt.plot(f, S21_mag[1:], label="Measured |S11|")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude |S11|")
plt.title("Magnitude S11")
plt.figtext(0.5, -0.05,'RawData 4.7117GHz probe 0 Dbm 215 mK', ha='center', fontsize=11, fontweight='bold')  
plt.legend()
plt.grid(True)

# %%
df=pd.read_csv(r"C:\Users\Anushka.PANDEY\Nextcloud\EPFL collab\sample1\reflection 50 ohms\VNA\Rawdata_5.020_GHz_probe_0dB_215mK.txt", sep='\t', header=0)  
Frequency = df.iloc[:,0]          # 1st column
Simag = df.iloc[:, 1]       # 2nd column
Sreal = df.iloc[:, 2]       # 3rd column

# Combine into complex S21
S21_complex = np.array([complex(r, i) for r, i in zip(Sreal, Simag)])

# Compute magnitude in dB
S21_mag = np.abs(S21_complex)
S21_dB = 20 * np.log10(S21_mag)
S21_dB = S21_dB[1:]
f = Frequency[1:]
S21_complex = S21_complex[1:]
# Plot magnitude fit
plt.figure(figsize=(10, 6))
plt.plot(f, S21_mag[1:], label="Measured |S11|")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude |S11|")
plt.title("Magnitude S11")
plt.figtext(0.5, -0.05,'Rawdata_5.020_GHz_probe_0dB_215mK', ha='center', fontsize=11, fontweight='bold')  
plt.legend()
plt.grid(True)

# %%
df=pd.read_csv(r"C:\Users\Anushka.PANDEY\Nextcloud\EPFL collab\sample1\reflection 50 ohms\VNA\Rawdata_5.0987_GHz_probe_0dB_215mK.txt", sep='\t', header=0)  
Frequency = df.iloc[:,0]          # 1st column
Simag = df.iloc[:, 1]       # 2nd column
Sreal = df.iloc[:, 2]       # 3rd column

# Combine into complex S21
S21_complex = np.array([complex(r, i) for r, i in zip(Sreal, Simag)])

# Compute magnitude in dB
S21_mag = np.abs(S21_complex)
S21_dB = 20 * np.log10(S21_mag)
S21_dB = S21_dB[1:]
f = Frequency[1:]
S21_complex = S21_complex[1:]
# Plot magnitude fit
plt.figure(figsize=(10, 6))
plt.plot(f, S21_mag[1:], label="Measured |S11|")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude |S11|")
plt.title("Magnitude S11")
plt.figtext(0.5, -0.05,'Rawdata_5.0987_GHz_probe_0dB_215mK', ha='center', fontsize=11, fontweight='bold')  
plt.legend()
plt.grid(True)

# %%
df=pd.read_csv(r"C:\Users\Anushka.PANDEY\Nextcloud\EPFL collab\sample1\reflection 50 ohms\VNA\Rawdata_5.9739_GHz_probe_0dB_215mK.txt" ,sep='\t', header=0)  
Frequency = df.iloc[:,0]          # 1st column
Simag = df.iloc[:, 1]       # 2nd column
Sreal = df.iloc[:, 2]       # 3rd column

# Combine into complex S21
S21_complex = np.array([complex(r, i) for r, i in zip(Sreal, Simag)])

# Compute magnitude in dB
S21_mag = np.abs(S21_complex)
S21_dB = 20 * np.log10(S21_mag)
S21_dB = S21_dB[1:]
f = Frequency[1:]
S21_complex = S21_complex[1:]
# Plot magnitude fit
plt.figure(figsize=(10, 6))
plt.plot(f, S21_mag[1:], label="Measured |S11|")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude |S11|")
plt.title("Magnitude S11")
plt.figtext(0.5, -0.05,'Rawdata_5.9739_GHz_probe_0dB_215mK', ha='center', fontsize=11, fontweight='bold')  
plt.legend()
plt.grid(True)

# %%
df=pd.read_csv(r"C:\Users\Anushka.PANDEY\Nextcloud\EPFL collab\sample1\reflection 50 ohms\VNA\Rawdata_7.3284_GHz_probe_0dB_215mK.txt", sep='\t', header=0)  
Frequency = df.iloc[:,0]          # 1st column
Simag = df.iloc[:, 1]       # 2nd column
Sreal = df.iloc[:, 2]       # 3rd column

# Combine into complex S21
S21_complex = np.array([complex(r, i) for r, i in zip(Sreal, Simag)])

# Compute magnitude in dB
S21_mag = np.abs(S21_complex)
S21_dB = 20 * np.log10(S21_mag)
S21_dB = S21_dB[1:]
f = Frequency[1:]
S21_complex = S21_complex[1:]
# Plot magnitude fit
plt.figure(figsize=(10, 6))
plt.plot(f, S21_mag[1:], label="Measured |S11|")
plt.xlabel("Frequency (Hz)")
plt.xlim(7.3e9, 7.4e9)
plt.ylabel("Magnitude |S11|")
plt.title("Magnitude S11")
plt.figtext(0.5, -0.05,'Rawdata_7.3284_GHz_probe_0dB_215mK', ha='center', fontsize=11, fontweight='bold')  
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Broad Sweep from 4GHz to 8 GHz to see the frequency dependence of the background

# %%
df=pd.read_csv( r"C:\Users\Anushka.PANDEY\Nextcloud\EPFL collab\sample1\reflection 50 ohms\VNA\Broad_sweep_s11.txt", sep='\t', header=0)  
Frequency = df.iloc[:,0]          # 1st column
Simag = df.iloc[:, 1]       # 2nd column
Sreal = df.iloc[:, 2]       # 3rd column

# Combine into complex S21
S11_complex = np.array([complex(r, i) for r, i in zip(Sreal, Simag)])

# Compute magnitude in dB
S11_mag = np.abs(S11_complex)
S11_dB = 20 * np.log10(S11_mag)
S11_dB = S11_dB[1:]
f = Frequency[1:]
S11_complex = S11_complex[1:]
# Plot magnitude fit
plt.figure(figsize=(10, 6))
plt.plot(f, S11_mag[1:], label="Measured |S11|")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude |S11|")
plt.title("Magnitude S11")
plt.figtext(0.5, -0.05,'Broad_sweep_s11_probe_0db', ha='center', fontsize=11, fontweight='bold')  
plt.legend()
plt.grid(True)

# %%
df = pd.read_csv(
    r"C:\Users\Anushka.PANDEY\Nextcloud\EPFL collab\sample1\reflection 50 ohms\VNA\Rawdata_5098.38187_GHz_pump_-31dB_probe_-50dB_215mK.txt",
    sep='\t', header=0
)
Frequency = df.iloc[:, 0]          # 1st column
Simag = df.iloc[:, 1]              # 2nd column
Sreal = df.iloc[:, 2]              # 3rd column

# Combine into complex S11
S11_complex = np.array([complex(r, i) for r, i in zip(Sreal, Simag)])

# Compute magnitude in dB
S11_mag = np.abs(S11_complex)
S11_dB = 20 * np.log10(S11_mag)
S11_dB = S11_dB[1:]
f = Frequency[1:]
S11_complex = S11_complex[1:]

file_path = r"C:\Users\Anushka.PANDEY\Nextcloud\EPFL collab\sample1\transmission configuration\EPFL sample 1 5.1 GHz 215 mK\215 mK cavity sweeps\5.09686043 GHz -31 dBm pump -41 dBm probe + opp line.txt"
freq = []
S21 = []
with open(file_path, 'r') as file:
    data = file.readlines()
for line in data[16:]:
    fields = line.split('\t')
    freq.append(float(fields[1]))
    S21.append(float(fields[2]))
freq = array(freq)
logMag = array(S21)

# Plot magnitude fit
plt.figure(figsize=(10, 6))
plt.plot(f, S11_dB, label="Measured |S11|")
plt.plot(freq * 1e9, logMag, label="Measured |S21|")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude |S11| and |S21| (dB)")
plt.xlim(5.095e9, 5.102e9)
plt.title("Comparison of S11 and S21")
plt.figtext(0.5, -0.05, 'Comparison_5.1_GHz_pump_-31dB_215mK', ha='center', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Plotting FSP data 215 mK

# %%
filenames=["analyser_5.09838188GHz_pump-31db_probe-50db_left_peak.txt", "analyser_5.09838188GHz_pump-36db_probe-55db_left_peak.txt",
]

def read_measurement_file(filename):
    """Reads measurement data from CSV files"""
    folder = r"C:\Users\Anushka.PANDEY\Nextcloud\EPFL collab\sample1\reflection 50 ohms\FSP"
    freq = []
    S = []
    with open(folder+"\\"+filename, 'r') as f:
        data = f.readlines()
    
    # Read each line and extract frequency and power
    for line in data:
        fields = line.strip().split()
        if len(fields) != 2:
            continue
        try:
            freq.append(float(fields[0]))
            S.append(float(fields[1]))
        except ValueError:
            continue  # Skip lines that can't be parsed

    return np.array(freq), np.array(S)
for filename in filenames:
    freq, power = read_measurement_file(filename)
    freq = np.array(freq)- 5.09838188e9
    power =np.array(power)
    # print(freq, power)
    plt.figure(figsize=(10, 6))
    plot(freq, power, label=f' ({filename.split("_")[2]})')
    plt.xlabel("Frequency (Hz)")
    plt.ylabel("Power (dBm)")
    # plt.xlim(-2e6, -1e6)
    plt.title("Mechanics 5.1 Ghz 215mK")
    plt.figtext(0.5, -0.05, filename, ha='center', fontsize=11, fontweight='bold')
    plt.legend()
    plt.grid(True)
    show()

# pumping at a higher frequency than resonance freq ( w + omega_m)
filename_1 = "analyser_5.09972187GHz_pump-31db_RBW_1Hz_left_peak.txt"
freq, power = read_measurement_file(filename_1)
freq = np.array(freq)-5.09972187e9
power = np.array(power)
# print(freq, power)
plt.figure(figsize=(10, 6))
plot(freq, power)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power (dBm)")
plt.title("Mechanics 5.1 Ghz 215mK{pumping at a higher frequency than resonance freq. ( w + omega_m)}")
plt.figtext(0.5, -0.05, 'analyser_5.09972187GHz_pump-31db_RBW_1Hz_left_peak', ha='center', fontsize=11, fontweight='bold')
plt.grid(True)
show()

# %%
filename = "analyser_5.09838188GHz_pump-31db_probe-50db_RBW_1Hz_left_peak_zoomed.txt"
freq, power = read_measurement_file(filename)
freq = np.array(freq)-5.09838188e9
power = np.array(power)
# print(freq, power)
plt.figure(figsize=(10, 6))
plot(freq, power)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power (dBm)")
plt.xlim(-1.5451e6, -1.5447e6)
plt.title("Mechanics 5.1 Ghz 215mK")
plt.figtext(0.5, -0.05, 'analyser_5.09838188GHz_pump-31db_probe-50db_RBW_1Hz_left_peak_zoomed', ha='center', fontsize=11, fontweight='bold')
plt.grid(True)
show()

filename = "analyser_5.09838188GHz_pump-31db_probe-50db_RBW_10Hz_left_peak_zoomed.txt"
freq, power = read_measurement_file(filename)
freq = np.array(freq)-5.09838188e9
power = np.array(power)
# print(freq, power)
plt.figure(figsize=(10, 6))
plot(freq, power)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power (dBm)")
plt.title("Mechanics 5.1 Ghz 215mK")
plt.figtext(0.5, -0.05, 'analyser_5.09838188GHz_pump-31db_probe-50db_RBW_10Hz_left_peak_zoomed', ha='center', fontsize=11, fontweight='bold')
plt.grid(True)
show()


filename_0="analyser_5.09838188GHz_pump-36db_probe-55db_RBW_1Hz_right_peak_zoomed.txt"
freq, power = read_measurement_file(filename_0)
freq = np.array(freq)- 5.09838188e9
power = np.array(power)
# print(freq, power)
plt.figure(figsize=(10, 6))
plot(freq, power, label=f' ({filename_0.split("_")[2]})')
plt.xlabel("Frequency (Hz)")
plt.xlim(1.4625e6, 1.4629e6)
plt.ylabel("Power (dBm)")
plt.title("Mechanics 5.1 Ghz 215mK{zoomed three peaks}")
plt.figtext(0.5, -0.05, 'analyser_5.09838188GHz_pump-36db_probe-55db_RBW_1Hz_right_peak_zoomed', ha='center', fontsize=11, fontweight='bold')
plt.legend()
plt.grid(True)
show()

# %% [markdown]
# Mechanics 5.02012Ghz 5dB right peak

# %%
filename_1 = "analyser_test1_5.02012GHz_pump_-41dB_right_peak.txt"
freq, power = read_measurement_file(filename_1)
f0 = freq[np.argmax(power)]
print(f'peak freq:{f0}')
freq = np.array(freq) - 5.02012e9
power = np.array(power)
# print(freq, power)
plt.figure(figsize=(10, 6))
plot(freq, power)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power (dBm)")
plt.title("Mechanics 5.02012GHz 215mK")
plt.figtext(0.5, -0.05, 'analyser_test1_5.02012GHz_pump_-41db_right_peak', ha='center', fontsize=11, fontweight='bold')

plt.grid(True)
show()
# Out:
# peak freq:5021466600.0

# %%
def read_measurement_file(filename):
    """Reads measurement data from CSV files"""
    folder = r"C:\Users\Anushka.PANDEY\Nextcloud\EPFL collab\sample1\reflection 50 ohms\FSP"
    freq = []
    S = []
    with open(folder+"\\"+filename, 'r') as f:
        data = f.readlines()
    
    # Read each line and extract frequency and power
    for line in data[45:]:
        fields = line.strip().split(',')
        if len(fields) != 2:
            continue
        try:
            freq.append(float(fields[0]))
            S.append(float(fields[1]))
        except ValueError:
            continue  # Skip lines that can't be parsed

    return np.array(freq), np.array(S)
filename_00="5.019737 GHz -41 dBm pump 215 mK 10 Hz RBW.csv"
freq, power = read_measurement_file(filename_00)
print(freq, power)
# f0 = freq[np.argmax(power)]
# print(f'peak freq:{f0}')
freq = np.array(freq)
power = np.array(power)
# print(freq, power)
plt.figure(figsize=(10, 6))
plot(freq, power)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power (dBm)")
plt.title("Mechanics 5.019737 GHz 215mK")
plt.figtext(0.5, -0.05, "5.019737 GHz -41 dBm pump 215 mK 10 Hz RBW.csv", ha='center', fontsize=11, fontweight='bold')

plt.grid(True)
show()

filename_1 = "5.019737 GHz -41 dBm pump 215 mK 1 Hz RBW_0000.csv"
freq, power = read_measurement_file(filename_1)
print(freq, power)
# f0 = freq[np.argmax(power)]
# print(f'peak freq:{f0}')
freq = np.array(freq)
power = np.array(power)
plt.figure(figsize=(10, 6))
plot(freq, power)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power (dBm)")
plt.title("Mechanics 5.019737 GHz 215mK")
plt.figtext(0.5, -0.05, "5.019737 GHz -41 dBm pump 215 mK 1 Hz RBW.csv", ha='center', fontsize=11, fontweight='bold')
plt.grid(True)
show()
# Out:
# [5.01723667e+09 5.01724167e+09 5.01724667e+09 ... 5.02222667e+09
#  5.02223167e+09 5.02223667e+09] [-104.73877921 -146.84466138 -103.26887068 ... -104.33688146 -145.06330545
#  -105.29280484]
# [5.01865661e+09 5.01865661e+09 5.01865661e+09 ... 5.01865760e+09
#  5.01865760e+09 5.01865761e+09] [-125.38426646 -119.91368866 -117.93136801 ... -121.87071051 -123.69080353
#  -127.6648941 ]
